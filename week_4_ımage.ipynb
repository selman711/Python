# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
my_img=cv2.imread("./aslan.webp",1)
my_img_grey=cv2.cvtColor(my_img,cv2.COLOR_BGR2GRAY)

# %%
_,my_tresh_binary=cv2.threshold(my_img_grey,128,255,type=cv2. THRESH_BINARY)
_,my_tresh_binary_inv=cv2.threshold(my_img_grey,128,255,type= cv2.THRESH_BINARY_INV)
_, my_tresh_tozero=cv2.threshold(my_img_grey,128,255,type=cv2.THRESH_TOZERO)
_, my_tresh_tozero_inv=cv2.threshold(my_img_grey,128,255,type=cv2.THRESH_TOZERO_INV)

# %%
fig=plt.figure(figsize=(10,7))
rows=2
colums=3

fig.add_subplot(rows,colums,1)
plt.imshow(my_img_grey,cmap="gray")
plt.axis("off")
pit.title("Origina Image")

fig.add_subplot(rows,colums,2)
plt.imshow(my_tresh_binary,cmap="gray")
plt.axis("off")
plt.title("BİNARY THRESHOLDING İMAGE")

fig.add_subplot(rows,colums,3)
plt.imshow(my_tresh_binary_inv,cmap="gray")
plt.axis("off")
plt.title("BİNARY INV THRESHOLDING İMAGE")

fig.add_subplot(rows,colums,4)
plt.imshow(my_tresh_trunc,cmap="gray")
plt.axis("off")
plt.title("BİNARY THRESHOLDING İMAGE")

fig.add_subplot(rows,colums,5)
plt.imshow(my_tresh_tozero,cmap="gray")
plt.axis("off")
plt.title("BİNARY THRESHOLDING İMAGE")

fig.add_subplot(rows,colums,6)
plt.imshow(my_tresh_tozero_inv,cmap="gray")
plt.axis("off")
plt.title("BİNARY THRESHOLDING İMAGE")

plt.tight_layout()
plt.savefig("./my_all_thresh_images.png",dpi=300)
plt.show()

# %%
_, my_tresh_trunc=cv2.threshold(my_img_grey,128,255,type=cv2. THRESH_TRUNC)

# %%
plt.imshow(my_tresh_tozero_inv,cmap="gray")
plt.axis("off")
plt.title("BİNARY THRESHOLDING İMAGE")

plt.tight_layout()
plt.savefig("./my_thresh_tozero.png",dpi=300)
plt.show()

# %%
img_gray=cv2.imread("./cameraman.jpg",0)
histr = cv2.calcHist  ([img_gray],[0] ,None,[256] ,[0,256])

plt.plot(histr)
plt.show()

# %%
img_camera=cv2.imread("./cameraman.jpg",0)
img_eq_hist=cv2.equalizeHist(img_camera)


fig=plt.figure(figsize=(10,7))
rows=1
colums=2

fig.add_subplot(rows,colums,1)
plt.imshow(img_camera,cmap="gray")
plt.axis("off")
pit.title("Origina Image")


fig.add_subplot(rows,colums,2)
plt.imshow(img_eq_hist,cmap="gray")
plt.axis("off")
pit.title("HİSTOGRAM IMAGE")
# Out:
# Text(0.5, 1.0, 'HİSTOGRAM IMAGE')

# %%
hist_ogr = cv2.calcHist  ([img_gray],[0] ,None,[256] ,[0,256])
hist_eq = cv2.calcHist  ([img_gray],[0] ,None,[256] ,[0,256])
plt.figure(figsize=(12,5))
plt.subplot (1,2,1)
plt.plot(hist_ogr,color="b")
plt.title("orjinal görüntü histogramı")

plt.subplot (1,2,2)
plt.plot(hist_eq,color="b")
plt.title("histogram eşitleme sonrası histogram")
plt.tight_layout()
plt.savefig("histogram_grafikleri.jpg",dpi=300)
plt.show()

# %%
clahe=cv2.createCLAHE(clipLimt
